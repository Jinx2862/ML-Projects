# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import plotly.express as pe
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
sns.set_theme(style = "darkgrid")
# Out:
# C:\Users\Ajinkya\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
df=pd.read_csv("marketing_campaign1 (1).csv")

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0  04-09-2012       58       635         88              546
# 1            1  08-03-2014       38        11          1                6
# 2            0  21-08-2013       26       426         49              127
# 3            0  10-02-2014       26        11          4               20
# 4            0  19-01-2014       94       173         43              118
# ...        ...         ...      ...       ...        ...              ...
# 2235         1  13-06-2013       46       709         43              182
# 2236         1  10-06-2014       56       406          0               30
# 2237         0  25-01-2014       91       908         48              217
# 2238         1  24-01-2014        8       428         30              214
# 2239         1  15-10-2012       40        84          3               61
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 172                88            88                  3
# 1                   2                 1             6                  2
# 2                 111                21            42                  1
# 3                  10                 3             5                  2
# 4                  46                27            15                  5
# ...               ...               ...           ...                ...
# 2235               42               118           247                  2
# 2236                0                 0             8                  7
# 2237               32                12            24                  1
# 2238               80                30            61                  2
# 2239                2                 1            21                  3
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   8                   10                  4
# 1                   1                    1                  2
# 2                   8                    2                 10
# 3                   2                    0                  4
# 4                   5                    3                  6
# ...               ...                  ...                ...
# 2235                9                    3                  4
# 2236                8                    2                  5
# 2237                2                    3                 13
# 2238                6                    5                 10
# 2239                3                    1                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     7             0             0             0
# 1                     5             0             0             0
# 2                     4             0             0             0
# 3                     6             0             0             0
# 4                     5             0             0             0
# ...                 ...           ...           ...           ...
# 2235                  5             0             0             0
# 2236                  7             0             0             0
# 2237                  6             0             1             0
# 2238                  3             0             0             0
# 2239                  7             0             0             0
#
#       AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response
# 0                0             0         0              3         11         1
# 1                0             0         0              3         11         0
# 2                0             0         0              3         11         0
# 3                0             0         0              3         11         0
# 4                0             0         0              3         11         0
# ...            ...           ...       ...            ...        ...       ...
# 2235             0             0         0              3         11         0
# 2236             1             0         0              3         11         0
# 2237             0             0         0              3         11         0
# 2238             0             0         0              3         11         0
# 2239             0             0         0              3         11         1
#
# [2240 rows x 29 columns]

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# min       0.000000     0.000000     0.000000         0.000000
# 25%      24.000000    23.750000     1.000000        16.000000
# 50%      49.000000   173.500000     8.000000        67.000000
# 75%      74.000000   504.250000    33.000000       232.000000
# max      99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# count      2240.000000       2240.000000   2240.000000        2240.000000
# mean         37.525446         27.062946     44.021875           2.325000
# std          54.628979         41.280498     52.167439           1.932238
# min           0.000000          0.000000      0.000000           0.000000
# 25%           3.000000          1.000000      9.000000           1.000000
# 50%          12.000000          8.000000     24.000000           2.000000
# 75%          50.000000         33.000000     56.000000           3.000000
# max         259.000000        263.000000    362.000000          15.000000
#
#        NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# count      2240.000000          2240.000000        2240.000000
# mean          4.084821             2.662054           5.790179
# std           2.778714             2.923101           3.250958
# min           0.000000             0.000000           0.000000
# 25%           2.000000             0.000000           3.000000
# 50%           4.000000             2.000000           5.000000
# 75%           6.000000             4.000000           8.000000
# max          27.000000            28.000000          13.000000
#
#        NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# count        2240.000000   2240.000000   2240.000000   2240.000000
# mean            5.316518      0.072768      0.074554      0.072768
# std             2.426645      0.259813      0.262728      0.259813
# min             0.000000      0.000000      0.000000      0.000000
# 25%             3.000000      0.000000      0.000000      0.000000
# 50%             6.000000      0.000000      0.000000      0.000000
# 75%             7.000000      0.000000      0.000000      0.000000
# max            20.000000      1.000000      1.000000      1.000000
#
#        AcceptedCmp1  AcceptedCmp2     Complain  Z_CostContact  Z_Revenue  \
# count   2240.000000   2240.000000  2240.000000         2240.0     2240.0
# mean       0.064286      0.013393     0.009375            3.0       11.0
# std        0.245316      0.114976     0.096391            0.0        0.0
# min        0.000000      0.000000     0.000000            3.0       11.0
# 25%        0.000000      0.000000     0.000000            3.0       11.0
# 50%        0.000000      0.000000     0.000000            3.0       11.0
# 75%        0.000000      0.000000     0.000000            3.0       11.0
# max        1.000000      1.000000     1.000000            3.0       11.0
#
#           Response
# count  2240.000000
# mean      0.149107
# std       0.356274
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
sns.distplot(df['Income'])
plt.show()

# %%
# FILL THE MISSING VALUES WITH THE MEDIAN VALUES.. 
df['Income']=df['Income'].fillna(df['Income'].median())

# %% [markdown]
# In above cell "Z_CostContact" and "Z_Revenue" have same value in all the rows that's why , they are not going to contribute anything in the model building. So we can drop them.

# %%
df=df.drop(columns=["Z_CostContact", "Z_Revenue"],axis=1)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Response               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#FINDING THE NUMBER OF UNIQUE VALUES PRESENT IN EACH COLUMN...
df.nunique()
# Out:
# ID                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1975
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Complain                  2
# Response                  2
# dtype: int64

# %% [markdown]
#  Dt_Customer indicates the date a customer joined the database so, convert the dtype of the column to datetime

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Create another feature "Spent" indicating the total amount spent by the customer in various categories over the span of two years.

# %%
df['Amount_Spent'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# %% [markdown]
# Create another feature "Living_With" out of "Marital_Status" to extract the living situation of couples.

# %%
df['Living_With'] = df['Marital_Status'].replace({'Married':'Partner', 'Together':'Partner', 'Absurd':'Alone', 'Widow':'Alone', 'YOLO':'Alone', 'Divorced':'Alone', 'Single':'Alone'})

# %% [markdown]
# Create a feature "Children" to indicate total children in a household that is, kids and teenagers.

# %%
df['Children'] = df['Kidhome'] + df['Teenhome']

# %% [markdown]
# To get further clarity of household, Creating feature indicating "Family_Size"

# %%
df['Family_Size'] = df['Living_With'].replace({'Alone': 1, 'Partner':2}) + df['Children']

# %% [markdown]
#  Seperating education levels in three groups

# %%
df['Education'] = df['Education'].replace({'Basic':'Undergraduate', '2n Cycle':'Undergraduate', 'Graduation':'Graduate', 'Master':'Postgraduate', 'PhD':'Postgraduate'})

# %% [markdown]
# Extract the "Age" of a customer by the "Year_Birth" indicating the birth year of the respective person.

# %%
df['Customer_Age'] = (pd.Timestamp('now').year) - df['Year_Birth']

# %%
df['Total_Purchases'] = df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases'] + df['NumDealsPurchases']

# %%
df['TotalAcceptedCmp'] = df['AcceptedCmp1'] + df['AcceptedCmp2'] + df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5']

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Postgraduate', 'Undergraduate'], dtype=object)

# %%
df['Education'] = df['Education'].map({'Undergraduate':0,'Graduate':1,'Postgraduate':2})
df['Living_With'] = df['Living_With'].map({'Alone':0,'Partner':1})

# %% [markdown]
# Dropping some of the unnecessary features

# %%
df=df.drop(columns=["Year_Birth","Marital_Status","ID","AcceptedCmp1" , "AcceptedCmp2", "AcceptedCmp3" , "AcceptedCmp4","AcceptedCmp5","NumWebVisitsMonth", "NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumDealsPurchases" , "Kidhome", "Teenhome","MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds",'Dt_Customer','Recency','Complain','Response'],axis=1)

# %%
df.head()
# Out:
#    Education   Income  Amount_Spent  Living_With  Children  Family_Size  \
# 0          1  58138.0          1617            0         0            1
# 1          1  46344.0            27            0         2            3
# 2          1  71613.0           776            1         0            2
# 3          1  26646.0            53            1         1            3
# 4          2  58293.0           422            1         1            3
#
#    Customer_Age  Total_Purchases  TotalAcceptedCmp
# 0            67               25                 0
# 1            70                6                 0
# 2            59               21                 0
# 3            40                8                 0
# 4            43               19                 0

# %%
df.describe()
# Out:
#          Education         Income  Amount_Spent  Living_With     Children  \
# count  2240.000000    2240.000000   2240.000000  2240.000000  2240.000000
# mean      1.267411   52237.975446    605.798214     0.644643     0.950446
# std       0.652347   25037.955891    602.249288     0.478728     0.751803
# min       0.000000    1730.000000      5.000000     0.000000     0.000000
# 25%       1.000000   35538.750000     68.750000     0.000000     0.000000
# 50%       1.000000   51381.500000    396.000000     1.000000     1.000000
# 75%       2.000000   68289.750000   1045.500000     1.000000     1.000000
# max       2.000000  666666.000000   2525.000000     1.000000     3.000000
#
#        Family_Size  Customer_Age  Total_Purchases  TotalAcceptedCmp
# count  2240.000000   2240.000000      2240.000000       2240.000000
# mean      2.595089     55.194196        14.862054          0.297768
# std       0.906959     11.984069         7.677173          0.678381
# min       1.000000     28.000000         0.000000          0.000000
# 25%       2.000000     47.000000         8.000000          0.000000
# 50%       3.000000     54.000000        15.000000          0.000000
# 75%       3.000000     65.000000        21.000000          0.000000
# max       5.000000    131.000000        44.000000          4.000000

# %%
df.shape
# Out:
# (2240, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Education         2240 non-null   int64
#  1   Income            2240 non-null   float64
#  2   Amount_Spent      2240 non-null   int64
#  3   Living_With       2240 non-null   int64
#  4   Children          2240 non-null   int64
#  5   Family_Size       2240 non-null   int64
#  6   Customer_Age      2240 non-null   int64
#  7   Total_Purchases   2240 non-null   int64
#  8   TotalAcceptedCmp  2240 non-null   int64
# dtypes: float64(1), int64(8)
# memory usage: 157.6 KB

# %% [markdown]
# ### Data Visualization

# %%
# Pairplot'
sns.pairplot(df)
plt.savefig('Pairplot.png')

# %%
# BoxPLot
fig, axes=plt.subplots(6,1,figsize=(14,12))
sns.boxplot(x='Income',data=df,palette='crest',ax=axes[0])
sns.boxplot(x='Amount_Spent',data=df,palette='crest',ax=axes[1])
sns.boxplot(x='Children',data=df,palette='crest',ax=axes[2])
sns.boxplot(x='Family_Size',data=df,palette='crest',ax=axes[3])
sns.boxplot(x='Customer_Age',data=df,palette='crest',ax=axes[4])
sns.boxplot(x='Total_Purchases',data=df,palette='crest',ax=axes[5])
plt.tight_layout()
plt.savefig('Boxplot.png')

# %%
df.corr()
# Out:
#                   Education    Income  Amount_Spent  Living_With  Children  \
# Education          1.000000  0.130344      0.096703    -0.007352  0.057994
# Income             0.130344  1.000000      0.664775     0.004684 -0.290858
# Amount_Spent       0.096703  0.664775      1.000000    -0.017744 -0.498888
# Living_With       -0.007352  0.004684     -0.017744     1.000000  0.039158
# Children           0.057994 -0.290858     -0.498888     0.039158  1.000000
# Family_Size        0.044192 -0.238627     -0.422907     0.560298  0.849596
# Customer_Age       0.181483  0.160899      0.111306    -0.004237  0.090199
# Total_Purchases    0.101008  0.563450      0.753903     0.006707 -0.245790
# TotalAcceptedCmp   0.031929  0.307122      0.459554     0.000032 -0.244282
#
#                   Family_Size  Customer_Age  Total_Purchases  TotalAcceptedCmp
# Education            0.044192      0.181483         0.101008          0.031929
# Income              -0.238627      0.160899         0.563450          0.307122
# Amount_Spent        -0.422907      0.111306         0.753903          0.459554
# Living_With          0.560298     -0.004237         0.006707          0.000032
# Children             0.849596      0.090199        -0.245790         -0.244282
# Family_Size          1.000000      0.072532        -0.200201         -0.202475
# Customer_Age         0.072532      1.000000         0.168304          0.000301
# Total_Purchases     -0.200201      0.168304         1.000000          0.257273
# TotalAcceptedCmp    -0.202475      0.000301         0.257273          1.000000

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap='magma')
plt.savefig('corr.png')

# %% [markdown]
# ### Outlier Detection

# %%
numerical = ['Income', 'Amount_Spent', 'Customer_Age']

# %%
def detect_outliers(d):
  for i in d:
    Q3, Q1 = np.percentile(df[i], [75 ,25])
    IQR = Q3 - Q1

    ul = Q3+1.5*IQR
    ll = Q1-1.5*IQR

    outliers = df[i][(df[i] > ul) | (df[i] < ll)]
    print(f'*** {i} outlier points***', '\n', outliers, '\n')

# %%
detect_outliers(numerical)
# Out:
# *** Income outlier points***
#  164     157243.0
# 617     162397.0
# 655     153924.0
# 687     160803.0
# 1300    157733.0
# 1653    157146.0
# 2132    156924.0
# 2233    666666.0
# Name: Income, dtype: float64
#
# *** Amount_Spent outlier points***
#  1179    2525
# 1492    2524
# 1572    2525
# Name: Amount_Spent, dtype: int64
#
# *** Customer_Age outlier points***
#  192    124
# 239    131
# 339    125
# Name: Customer_Age, dtype: int64

# %% [markdown]
# We will delete some of the outlier points.

# %%
df = df[(df['Customer_Age']<100)]
df = df[(df['Income']<300000)]

# %%
df.shape
# Out:
# (2236, 9)

# %% [markdown]
# ### Feature Scaling

# %%
# Converting the Data Into the Standard Format
sc = StandardScaler()
x = sc.fit_transform(df)
df = pd.DataFrame(x, columns = df.columns)

# %%
df.head(5)
# Out:
#    Education    Income  Amount_Spent  Living_With  Children  Family_Size  \
# 0  -0.411891  0.288947      1.680176    -1.347635 -1.264308    -1.758810
# 1  -0.411891 -0.262003     -0.962202    -1.347635  1.395139     0.445618
# 2  -0.411891  0.918423      0.282541     0.742041 -1.264308    -0.656596
# 3  -0.411891 -1.182183     -0.918994     0.742041  0.065416     0.445618
# 4   1.123090  0.296187     -0.305762     0.742041  0.065416     0.445618
#
#    Customer_Age  Total_Purchases  TotalAcceptedCmp
# 0      1.016868         1.319340         -0.438933
# 1      1.273264        -1.155857         -0.438933
# 2      0.333146         0.798246         -0.438933
# 3     -1.290693        -0.895310         -0.438933
# 4     -1.034298         0.537699         -0.438933

# %% [markdown]
# ##  Model Building

# %% [markdown]
# ###  1.K-Means

# %%
df1 = df.copy()

# %%
km=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(df1)
    km.append(kmeans.inertia_)

# %% [markdown]
# Inertia measures how well a dataset was clustered by K-Means. It is calculated by measuring the distance between each data point and its centroid, squaring this distance, and summing these squares across one cluster

# %%
plt.figure(figsize=(16,8))
plt.plot(range(1,11),km, 'bx-')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('K-MEANS')
plt.show()
plt.savefig('Elbow-graph.png')

# %% [markdown]
# We can understand from the plot that cluster = 2 is the best...

# %%
kmeans=KMeans(n_clusters=2).fit(df1)
pred=kmeans.predict(df1)

# %%
df1['cluster_Kmeans'] = pred

# %% [markdown]
# The silhouette score is a metric for evaluating the quality of clusters created by a clustering algorithm. It ranges from -1 to 1, with higher values indicating better clustering.

# %%
silhouette_score(x,pred)
# Out:
# 0.25765978572404596

# %%
model = SilhouetteVisualizer(KMeans(n_clusters=2))
vis = model.fit(x)
vis.show()
plt.savefig('Silhoute-plot.png')

# %%
df1.head()
# Out:
#    Education    Income  Amount_Spent  Living_With  Children  Family_Size  \
# 0  -0.411891  0.288947      1.680176    -1.347635 -1.264308    -1.758810
# 1  -0.411891 -0.262003     -0.962202    -1.347635  1.395139     0.445618
# 2  -0.411891  0.918423      0.282541     0.742041 -1.264308    -0.656596
# 3  -0.411891 -1.182183     -0.918994     0.742041  0.065416     0.445618
# 4   1.123090  0.296187     -0.305762     0.742041  0.065416     0.445618
#
#    Customer_Age  Total_Purchases  TotalAcceptedCmp  cluster_Kmeans
# 0      1.016868         1.319340         -0.438933               1
# 1      1.273264        -1.155857         -0.438933               0
# 2      0.333146         0.798246         -0.438933               1
# 3     -1.290693        -0.895310         -0.438933               0
# 4     -1.034298         0.537699         -0.438933               0

# %% [markdown]
# ## Visualizing the Clusters Formed.

# %%
sns.countplot(x=df1["cluster_Kmeans"])
plt.title("Distribution Of The Clusters")
plt.show()
plt.savefig('kmeans.png')

# %%
sns.scatterplot(x=df1['Amount_Spent'],y=df1['Income'],hue=df1['cluster_Kmeans'])
plt.savefig('Amt_spent-income.png')

# %%
sns.scatterplot(x=df1['Amount_Spent'],y=df1['Education'],hue=df1['cluster_Kmeans'])
plt.savefig('Amt_spent-Edu.png')

# %%
sns.scatterplot(x=df1['Amount_Spent'],y=df1['Children'],hue=df1['cluster_Kmeans'])
plt.savefig('Amt_spent-Child.png')

# %%
sns.scatterplot(x=df1['Education'],y=df1['Income'],hue=df1['cluster_Kmeans'])
plt.savefig('Edu-income.png')

# %%
sns.scatterplot(x=df1['Amount_Spent'],y=df1['Customer_Age'],hue=df1['cluster_Kmeans'])
plt.savefig('Amt_spent-Customer_Age.png')

# %%
sns.scatterplot(x=df1['Amount_Spent'],y=df1['Living_With'],hue=df1['cluster_Kmeans'])
plt.savefig('Amt_spent-living.png')

# %% [markdown]
# ### 2.Hierarchical Clustering

# %%
df2=df.copy()

# %% [markdown]
# ##### A dendrogram is a diagram that shows the attribute distances between each pair of sequentially merged classes.

# %% [markdown]
# ##### The dendrogram from hierarchical clustering reveals the hierarchy of clusters at different levels, highlighting natural groupings in the data.

# %%
# We plot the Dendogram with the Minimum Distance
lk = hierarchy.linkage(df2,method='single', metric='euclidean') # Linkage is the distance between data point and clusters.
dendrogram = hierarchy.dendrogram(lk)
plt.savefig('single-dendro.png')

# %% [markdown]
# Here, clusters are overlapping with each other.

# %% [markdown]
# So, We plot the dendrogram by considering the maximum distance.

# %%
# We plot the Dendogram with the Maximum Distance
lk = hierarchy.linkage(df2,method='complete', metric='euclidean')
dendrogram = hierarchy.dendrogram(lk)
plt.savefig('complete-dendro.png')

# %%
lk = hierarchy.linkage(df2,method='complete', metric='euclidean')
dendrogram = hierarchy.dendrogram(lk)
plt.axhline(y = 9 , c = 'black', linestyle = '--')

# %%
hc = AgglomerativeClustering(n_clusters=3)
ypred = hc.fit_predict(df2)

# %%
ypred
# Out:
# array([0, 2, 0, ..., 0, 0, 2], dtype=int64)

# %%
df2['Cluster'] = ypred
df2.head()
# Out:
#    Education    Income  Amount_Spent  Living_With  Children  Family_Size  \
# 0  -0.411891  0.288947      1.680176    -1.347635 -1.264308    -1.758810
# 1  -0.411891 -0.262003     -0.962202    -1.347635  1.395139     0.445618
# 2  -0.411891  0.918423      0.282541     0.742041 -1.264308    -0.656596
# 3  -0.411891 -1.182183     -0.918994     0.742041  0.065416     0.445618
# 4   1.123090  0.296187     -0.305762     0.742041  0.065416     0.445618
#
#    Customer_Age  Total_Purchases  TotalAcceptedCmp  Cluster
# 0      1.016868         1.319340         -0.438933        0
# 1      1.273264        -1.155857         -0.438933        2
# 2      0.333146         0.798246         -0.438933        0
# 3     -1.290693        -0.895310         -0.438933        1
# 4     -1.034298         0.537699         -0.438933        1

# %%
silhouette_score(x,ypred)
# Out:
# 0.1780318935455148

# %%
ymodel = SilhouetteVisualizer(KMeans(n_clusters=3))
vis1 = ymodel.fit(x)
vis1.show()
# Out:
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 2236 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ## Visualizing the Clusters Formed

# %%
sns.countplot(x=df2["Cluster"])
plt.title("Distribution Of The Clusters")
plt.show()
plt.savefig('hierarchy.png')

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# We are going to use the K-means Model for Deployment

# %% [markdown]
# ### Cluster 0:
# 1.People with less expenses
#
# 2.people who are married and parents of more than 3 kids
#
# 3.people with low income
#
#
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
#
# ### Cluster 1:
# 1.people with more expenses
#
# 2.people who are single or parents who have less than 3 kids
#
# 3.people with high income
#
# 4.Age is not the criteria but it is observed to some extent that people who are older fall in this group

# %% [markdown]
# Therefore, we can say that the customers falling in cluster 1 likes to spend more.
# so the Firm's can target people falling in cluster 2 for the sale of their Products.

# %%
import pickle 
with open('kmeans.pkl','wb') as file:
    pickle.dump(kmeans,file)

# %%
# Loading the model
with open('kmeans.pkl','rb') as f:
    h = pickle.load(f)
